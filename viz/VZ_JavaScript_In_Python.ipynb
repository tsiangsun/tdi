# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 144

# %% [markdown]
# # JS Visualization in Python
#
# Along the spectrum of libraries ranging from pure D3.js to high level Python packages like Pandas, there are a number of JavaScript wrappers that attempt to provide the best JS visualization functionality for use with Python code and data. Usually, this comes at the expense of customizability and low-level control.
#
# This notebook will demo a popular mapping library called Folium, which wraps around Leaflet for interactive mapping functionality. Other Pyhthon visualization libraries also support JavaScript, including:
#
# * [Bokeh](http://bokeh.pydata.org/en/latest/docs/user_guide/interaction/callbacks.html#userguide-interaction-actions-widget-callbacks)
# * [Plotly](https://plot.ly/python/#chart-events)

# %% [markdown]
# ## JS Callbacks in Bokeh
#
# Examples below are taken from the official doc:
# http://bokeh.pydata.org/en/latest/docs/user_guide/interaction/callbacks.html

# %%
from bokeh.layouts import column
from bokeh.models import *
from bokeh.plotting import Figure, output_file, show
from bokeh.io import output_notebook, reset_output
from random import random

reset_output()
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f297706e-1498-4eb3-b08f-11c148ae8504">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Widget callbacks

# %%
x = [x*0.005 for x in range(0, 200)]
y = x

source = ColumnDataSource(data=dict(x=x, y=y))

plot = Figure(plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var f = cb_obj.value
    x = data['x']
    y = data['y']
    for (i = 0; i < x.length; i++) {
        y[i] = Math.pow(x[i], f)
        if (y[i]>0.8 ) {
            delete y[i]
            delete x[i]
        }
    }
    source.trigger('change');
""")

slider = Slider(start=0.1, end=4, value=1, step=.1, title="power")
# slider = Slider(start=0.1, end=4, value=1, step=.1, title="power", callback=callback)
slider.js_on_change('value', callback)

layout = column(slider, plot)

show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9df584fd-b42c-46b5-93f1-3cf9b2e577c8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("9df584fd-b42c-46b5-93f1-3cf9b2e577c8").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9df584fd-b42c-46b5-93f1-3cf9b2e577c8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9df584fd-b42c-46b5-93f1-3cf9b2e577c8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"328a40d8-4228-4385-9476-1e1a82d8394c":{"roots":{"references":[{"attributes":{},"id":"b7098616-fd04-4a09-a7db-997adc504412","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"776d35a2-2127-4ba0-be84-3495f77532fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"428ec0e2-a3d3-49f8-a340-55ab5c879c24","type":"BasicTicker"}},"id":"3440476e-c34b-403a-8d48-5283dba1c71e","type":"Grid"},{"attributes":{"plot":{"id":"776d35a2-2127-4ba0-be84-3495f77532fb","subtype":"Figure","type":"Plot"}},"id":"9673575b-27ed-4551-af37-22e9091d1eec","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"d52092fe-7918-4a42-99e9-a90bcf3785e8","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"98b671c4-5a58-423e-9674-3c003d9b6a79","type":"Title"},{"attributes":{"overlay":{"id":"68c38bb3-e2ee-4dad-915d-6230a96367b5","type":"BoxAnnotation"},"plot":{"id":"776d35a2-2127-4ba0-be84-3495f77532fb","subtype":"Figure","type":"Plot"}},"id":"3b561432-22dd-4e13-8bf8-170b023ce8d2","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"776d35a2-2127-4ba0-be84-3495f77532fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"43bbcdef-a96f-47e2-b726-4b2a02105925","type":"BasicTicker"}},"id":"03722407-d0a2-4f16-8ae2-9b314651f919","type":"Grid"},{"attributes":{"callback":null},"id":"36781379-bb18-4674-9fc5-c566f9b32bc0","type":"DataRange1d"},{"attributes":{"formatter":{"id":"fe623f20-27be-4712-b0b9-6441ef769916","type":"BasicTickFormatter"},"plot":{"id":"776d35a2-2127-4ba0-be84-3495f77532fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"428ec0e2-a3d3-49f8-a340-55ab5c879c24","type":"BasicTicker"}},"id":"3efc7547-ce74-487c-ba45-5819c7a27a52","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.005,0.01,0.015,0.02,0.025,0.03,0.035,0.04,0.045,0.05,0.055,0.06,0.065,0.07,0.075,0.08,0.085,0.09,0.095,0.1,0.105,0.11,0.115,0.12,0.125,0.13,0.135,0.14,0.145,0.15,0.155,0.16,0.165,0.17,0.17500000000000002,0.18,0.185,0.19,0.195,0.2,0.20500000000000002,0.21,0.215,0.22,0.225,0.23,0.23500000000000001,0.24,0.245,0.25,0.255,0.26,0.265,0.27,0.275,0.28,0.28500000000000003,0.29,0.295,0.3,0.305,0.31,0.315,0.32,0.325,0.33,0.335,0.34,0.34500000000000003,0.35000000000000003,0.355,0.36,0.365,0.37,0.375,0.38,0.385,0.39,0.395,0.4,0.405,0.41000000000000003,0.41500000000000004,0.42,0.425,0.43,0.435,0.44,0.445,0.45,0.455,0.46,0.465,0.47000000000000003,0.47500000000000003,0.48,0.485,0.49,0.495,0.5,0.505,0.51,0.515,0.52,0.525,0.53,0.535,0.54,0.545,0.55,0.555,0.56,0.5650000000000001,0.5700000000000001,0.5750000000000001,0.58,0.585,0.59,0.595,0.6,0.605,0.61,0.615,0.62,0.625,0.63,0.635,0.64,0.645,0.65,0.655,0.66,0.665,0.67,0.675,0.68,0.685,0.6900000000000001,0.6950000000000001,0.7000000000000001,0.705,0.71,0.715,0.72,0.725,0.73,0.735,0.74,0.745,0.75,0.755,0.76,0.765,0.77,0.775,0.78,0.785,0.79,0.795,0.8,0.805,0.81,0.8150000000000001,0.8200000000000001,0.8250000000000001,0.8300000000000001,0.835,0.84,0.845,0.85,0.855,0.86,0.865,0.87,0.875,0.88,0.885,0.89,0.895,0.9,0.905,0.91,0.915,0.92,0.925,0.93,0.935,0.9400000000000001,0.9450000000000001,0.9500000000000001,0.9550000000000001,0.96,0.965,0.97,0.975,0.98,0.985,0.99,0.995],"y":[0.0,0.005,0.01,0.015,0.02,0.025,0.03,0.035,0.04,0.045,0.05,0.055,0.06,0.065,0.07,0.075,0.08,0.085,0.09,0.095,0.1,0.105,0.11,0.115,0.12,0.125,0.13,0.135,0.14,0.145,0.15,0.155,0.16,0.165,0.17,0.17500000000000002,0.18,0.185,0.19,0.195,0.2,0.20500000000000002,0.21,0.215,0.22,0.225,0.23,0.23500000000000001,0.24,0.245,0.25,0.255,0.26,0.265,0.27,0.275,0.28,0.28500000000000003,0.29,0.295,0.3,0.305,0.31,0.315,0.32,0.325,0.33,0.335,0.34,0.34500000000000003,0.35000000000000003,0.355,0.36,0.365,0.37,0.375,0.38,0.385,0.39,0.395,0.4,0.405,0.41000000000000003,0.41500000000000004,0.42,0.425,0.43,0.435,0.44,0.445,0.45,0.455,0.46,0.465,0.47000000000000003,0.47500000000000003,0.48,0.485,0.49,0.495,0.5,0.505,0.51,0.515,0.52,0.525,0.53,0.535,0.54,0.545,0.55,0.555,0.56,0.5650000000000001,0.5700000000000001,0.57 ...

# %% [markdown]
# ### Tool callbacks

# %%
source = ColumnDataSource(data=dict(x=[], y=[], width=[], height=[]))

callback = CustomJS(args=dict(source=source), code="""
        // get data source from Callback args
        var data = source.data;

        /// get BoxSelectTool dimensions from cb_data parameter of Callback
        var geometry = cb_data['geometry'];

        /// calculate Rect attributes
        var width = geometry['x1'] - geometry['x0'];
        var height = geometry['y1'] - geometry['y0'];
        var x = geometry['x0'] + width/2;
        var y = geometry['y0'] + height/2;

        /// update data source with new Rect attributes
        data['x'].push(x);
        data['y'].push(y);
        data['width'].push(width);
        data['height'].push(height);

        // trigger update of data source
        source.trigger('change');
    """)

box_select = BoxSelectTool(callback=callback)

p = Figure(plot_width=400,
            plot_height=400,
            tools=[box_select, "reset"],  # Note this syntax
            title="Select Below",
            x_range=Range1d(start=0.0, end=1.0),
            y_range=Range1d(start=0.0, end=1.0))

rect = Rect(x='x',
            y='y',
            width='width',
            height='height',
            fill_alpha=0.3,
            fill_color='#009933')

p.add_glyph(source, rect, selection_glyph=rect, nonselection_glyph=rect)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0fc34663-26ff-45bf-8379-537cd085d762"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0fc34663-26ff-45bf-8379-537cd085d762").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0fc34663-26ff-45bf-8379-537cd085d762");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0fc34663-26ff-45bf-8379-537cd085d762' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ade19d7f-1f50-489d-9ef0-34ca82f84582":{"roots":{"references":[{"attributes":{"callback":{"id":"08ebdfc6-cdab-4a73-ad29-db3a53e06bd6","type":"CustomJS"},"overlay":{"id":"23fb8aff-bc30-49af-abd8-c4abfd2160b9","type":"BoxAnnotation"},"plot":{"id":"8fbe1047-e2ca-41ec-98bd-6f2981d6135f","subtype":"Figure","type":"Plot"}},"id":"8f290a18-13fe-4faa-b03b-db4c53b23264","type":"BoxSelectTool"},{"attributes":{"data_source":{"id":"83e6616d-738c-454e-a97f-ef62a598c582","type":"ColumnDataSource"},"glyph":{"id":"a19de8ed-1ddf-4ba8-9579-fe4840749477","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"a19de8ed-1ddf-4ba8-9579-fe4840749477","type":"Rect"},"selection_glyph":{"id":"a19de8ed-1ddf-4ba8-9579-fe4840749477","type":"Rect"}},"id":"4d6188d7-32bd-4b4c-a6f9-4be5f315ba28","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"cddf6172-0dbc-4ea1-99e5-f5a62f3285c9","type":"Range1d"},{"attributes":{"below":[{"id":"1b592534-5b14-4732-91da-3ea169b2a7da","type":"LinearAxis"}],"left":[{"id":"1963bf2d-4a21-4002-80ac-018bca227942","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"1b592534-5b14-4732-91da-3ea169b2a7da","type":"LinearAxis"},{"id":"da999ede-3d46-4c63-9b84-73e12f7ae792","type":"Grid"},{"id":"1963bf2d-4a21-4002-80ac-018bca227942","type":"LinearAxis"},{"id":"d26d34b0-a49f-4cad-a2c3-1039089b1e73","type":"Grid"},{"id":"23fb8aff-bc30-49af-abd8-c4abfd2160b9","type":"BoxAnnotation"},{"id":"4d6188d7-32bd-4b4c-a6f9-4be5f315ba28","type":"GlyphRenderer"}],"title":{"id":"82e31772-7bf6-42ed-bc43-f6045267921c","type":"Title"},"tool_events":{"id":"0e01bb54-6dfb-461c-8edb-ca4b2cedd738","type":"ToolEvents"},"toolbar":{"id":"79572230-1643-4875-8fed-4da7c113d030","type":"Toolbar"},"x_range":{"id":"cddf6172-0dbc-4ea1-99e5-f5a62f3285c9","type":"Range1d"},"y_range":{"id":"24322ca6-2fc8-41e5-b2e0-2739f1c47a83","type":"Range1d"}},"id":"8fbe1047-e2ca-41ec-98bd-6f2981d6135f","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"8fbe1047-e2ca-41ec-98bd-6f2981d6135f","subtype":"Figure","type":"Plot"},"ticker":{"id":"ea9e9290-5c9b-408c-b10f-0c97fcae912f","type":"BasicTicker"}},"id":"d26d34b0-a49f-4cad-a2c3-1039089b1e73","type":"Grid"},{"attributes":{},"id":"4e1213ec-c1c0-4dfd-a129-f571513f950a","type":"BasicTickFormatter"},{"attributes":{},"id":"0e01bb54-6dfb-461c-8edb-ca4b2cedd738","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["y","width","height","x"],"data":{"height":[],"width":[],"x":[],"y":[]}},"id":"83e6616d-738c-454e-a97f-ef62a598c582","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"23fb8aff-bc30-49af-abd8-c4abfd2160b9","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"24322ca6-2fc8-41e5-b2e0-2739f1c47a83","type":"Range1d"},{"attributes":{"plot":null,"text":"Select Below"},"id":"82e31772-7bf6-42ed-bc43-f6045267921c","type":"Title"},{"attributes":{},"id":"9771cba4-3471-4949-8aeb-c38cfe26fa10","type":"BasicTickFormatter"},{"attributes":{"args":{"source":{"id":"83e6616d-738c-454e-a97f-ef62a598c582","type":"ColumnDataSource"}},"code":"\n        // get data source from Callback args\n        var data = source.data;\n\n        /// get BoxSelectTool dimensions from cb_data parameter of Callback\n        var geometry = cb_data['geometry'];\n\n        /// calculate Rect attributes\n        var width = geometry['x1'] - geometry['x0'];\n        var height = geometry['y1'] - geometry['y0'];\n        var x = geometry['x0'] + width/2;\n        var y = geometry['y0'] + height/2;\n\n        /// update data source with new Rect attributes\n        data['x'].push(x);\n        data['y'].push(y);\n        data['width'].push(width);\n        data['height ...

# %% [markdown]
# **Question**: How would you allow the user to erase the glyphs?

# %%
x = [random() for x in range(500)]
y = [random() for y in range(500)]
color = ["navy"] * len(x)

s = ColumnDataSource(data=dict(x=x, y=y, color=color))
p = Figure(plot_width=400, plot_height=400, tools="lasso_select, reset", title="Select Here")
p.circle('x', 'y', color='color', size=8, source=s, alpha=0.4)

s2 = ColumnDataSource(data=dict(x=[0, 1], ym=[0.5, 0.5]))
p.line(x='x', y='ym', color="orange", line_width=5, alpha=0.6, source=s2)

s.callback = CustomJS(args=dict(s2=s2), code="""
        var inds = cb_obj.selected['1d'].indices;
        var d = cb_obj.data;
        var ym = 0

        if (inds.length == 0) { return; }

        for (i = 0; i < d['color'].length; i++) {
            d['color'][i] = "navy"
        }
        for (i = 0; i < inds.length; i++) {
            d['color'][inds[i]] = "firebrick"
            ym += d['y'][inds[i]]
        }

        ym /= inds.length
        s2.data['ym'] = [ym, ym]

        cb_obj.trigger('change');
        s2.trigger('change');
    """)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c939b8b8-712a-45d0-9dc8-af699484b748"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c939b8b8-712a-45d0-9dc8-af699484b748").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c939b8b8-712a-45d0-9dc8-af699484b748");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c939b8b8-712a-45d0-9dc8-af699484b748' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f9ca2040-2aaf-43b8-8b20-3c44cb35b335":{"roots":{"references":[{"attributes":{"plot":{"id":"bc73c0d7-ad5a-4bed-bb7b-15d09777f427","subtype":"Figure","type":"Plot"}},"id":"63e5939d-5012-4e12-88d6-72da99e24f2d","type":"ResetTool"},{"attributes":{},"id":"695ba9ab-d294-4619-b3ea-7f08d9291e70","type":"BasicTicker"},{"attributes":{"callback":{"id":"ddc75932-cc0c-404b-af38-6f0671c9424f","type":"CustomJS"},"column_names":["color","y","x"],"data":{"color":["navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy","navy"],"x":[0.66627318432 ...

# %%
p = Figure(plot_width=400, plot_height=400,
           tools="tap", title="Click the Dots")

source = ColumnDataSource(data=dict(
    x=[1, 2, 3, 4, 5],
    y=[2, 5, 8, 2, 7],
    color=["navy", "orange", "olive", "firebrick", "gold"]
    ))

p.circle('x', 'y', color='color', size=20, source=source)

url = "http://www.colors.commutercreative.com/@color/"
taptool = p.select(type=TapTool)
taptool.callback = OpenURL(url=url)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e00a13ea-6951-473b-8944-77f99aefc474"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e00a13ea-6951-473b-8944-77f99aefc474").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e00a13ea-6951-473b-8944-77f99aefc474");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e00a13ea-6951-473b-8944-77f99aefc474' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"47f8d0e3-df34-43a0-a67c-efa9c31ad2fd":{"roots":{"references":[{"attributes":{"plot":null,"text":"Click the Dots"},"id":"babdd095-63bd-4987-806d-a0b7f130922a","type":"Title"},{"attributes":{},"id":"1f035aef-61ff-452f-bfb4-7919fc50c2d8","type":"BasicTicker"},{"attributes":{},"id":"a1519288-a6bb-48f7-87b2-527359676822","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"3151905e-7958-44c1-88ba-78c19598b725","type":"DataRange1d"},{"attributes":{"plot":{"id":"dc3799fc-8bad-496c-a3b9-896a33feaf46","subtype":"Figure","type":"Plot"},"ticker":{"id":"40d0a417-2662-4a5d-ac58-38c2825b16bc","type":"BasicTicker"}},"id":"cba7444f-b23f-4302-93c5-68cd783674fc","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"377b2ba4-4adb-4f4e-af1e-1090efb0e71e","type":"TapTool"}]},"id":"0feacaed-2445-4bf8-9733-98148e314764","type":"Toolbar"},{"attributes":{"url":"http://www.colors.commutercreative.com/@color/"},"id":"d75d5b6f-2904-49c8-b1f5-88759651ed6a","type":"OpenURL"},{"attributes":{"callback":null,"column_names":["color","y","x"],"data":{"color":["navy","orange","olive","firebrick","gold"],"x":[1,2,3,4,5],"y":[2,5,8,2,7]}},"id":"87c1b0a6-c579-4025-97b3-7e06ac4d31fa","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"4a0145d7-202c-4ec3-97d0-2ed38bd0a32e","type":"BasicTickFormatter"},"plot":{"id":"dc3799fc-8bad-496c-a3b9-896a33feaf46","subtype":"Figure","type":"Plot"},"ticker":{"id":"1f035aef-61ff-452f-bfb4-7919fc50c2d8","type":"BasicTicker"}},"id":"7653fd9f-35a4-46e1-8139-d40ec1eb35bf","type":"LinearAxis"},{"attributes":{"fill_color":{"field":"color"},"line_color":{"field":"color"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"6b15970a-3ec4-41b5-833d-163d54bcf64e","type":"Circle"},{"attributes":{"callback":{"id":"d75d5b6f-2904-49c8-b1f5-88759651ed6a","type":"OpenURL"},"plot":{"id":"dc3799fc-8bad-496c-a3b9-896a33feaf46","subtype":"Figure","type":"Plot"}},"id":"377b2ba4-4adb-4f4e-af1e-1090efb0e71e","type":"TapTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"8d270f0a-d0be-411d-ac66-531b06088995","type":"Circle"},{"attributes":{"data_source":{"id":"87c1b0a6-c579-4025-97b3-7e06ac4d31fa","type":"ColumnDataSource"},"glyph":{"id":"6b15970a-3ec4-41b5-833d-163d54bcf64e","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"8d270f0a-d0be-411d-ac66-531b06088995","type":"Circle"},"selection_glyph":null},"id":"d3c69560-f8ec-413e-9414-b85dd20e038b","type":"GlyphRenderer"},{"attributes":{},"id":"4a0145d7-202c-4ec3-97d0-2ed38bd0a32e","type":"BasicTickFormatter"},{"attributes":{},"id":"79813d60-243c-45ad-9697-fa4818ac8041","type":"ToolEvents"},{"attributes":{"below":[{"id":"f8132e55-9167-4a7d-ae17-7fd8d551d351","type":"LinearAxis"}],"left":[{"id":"7653fd9f-35a4-46e1-8139-d40ec1eb35bf","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"f8132e55-9167-4a7d-ae17-7fd8d551d351","type":"LinearAxis"},{"id":"cba7444f-b23f-4302-93c5-68cd783674fc","type":"Grid"},{"id":"7653fd9f-35a4-46e1-8139-d40ec1eb35bf","type":"LinearAxis"},{"id":"08206e21-f1bc-4097-a342-9b068fcac800","type":"Grid"},{"id":"d3c69560-f8ec-413e-9414-b85dd20e038b","type":"GlyphRenderer"}],"title":{"id":"babdd095-63bd-4987-806d-a0b7f130922a","type":"Title"},"tool_events":{"id":"79813d60-243c-45ad-9697-fa4818ac8041","type":"ToolEvents"},"toolbar":{"id":"0feacaed-2445-4bf8-9733-98148e314764","type":"Toolbar"},"x_range":{"id":"3151905e-7958-44c1-88ba-78c19598b725","type":"DataRange1d"},"y_range":{"id":"bb66db87-349d-4e09-8856-0df3b51c8bc0","type":"DataRange1d"}},"id":"dc3799fc-8bad-496c-a3b9-896a33feaf46","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"bb66db87-349d-4e09-8856-0df3b51c8bc0","type":"DataRange1d"},{"attributes":{"dimension":1,"plot" ...

# %% [markdown]
# ## Folium
#
# GitHub: https://github.com/python-visualization/folium
#
# Doc: https://folium.readthedocs.io/en/latest/

# %%
import folium
map = folium.Map(location=[38.9071923, -77.0368707])
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
import geocoder
location = 'King Arthur\'s Seat'
loc = geocoder.google(location)
loc.latlng
# Out:
# [55.9440833, -3.1618333]

# %%
map = folium.Map(location=loc.latlng, zoom_start=15)
folium.Marker(loc.latlng, popup=location).add_to(map)
#folium.CircleMarker(loc.latlng, popup=location, radius=15, color='#3186cc', fill_color='#3186cc').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# **Exercise**: You can add markers to the map programmatically. Try using requests to get lat/long data from an API or adding the location of tweets as they come in.

# %%
# Extract HTML for embedding
# map.save('map.html')

# %% [markdown]
# *Copyright &copy; 2017 The Data Incubator.  All rights reserved.*
